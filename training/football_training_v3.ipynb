# %%
# %pip install ultralytics
# %pip install roboflow
# Out:
# Requirement already satisfied: ultralytics in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (8.4.61)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from ultralytics) (2.4.6)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from ultralytics) (3.10.9)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from ultralytics) (12.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from ultralytics) (2.34.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from ultralytics) (1.17.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from ultralytics) (2.12.0+cu130)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from ultralytics) (0.27.0+cu130)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from ultralytics) (1.41.2)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from ultralytics) (2.0.20)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=3 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.41.2 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from polars>=0.20.0->ultralytics) (1.41.2)
# Requirement already satisfied: six>=1.5 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2026.5.20)
# Requirement already satisfied: filelock in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.29.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (2026.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: roboflow in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (1.3.9)
# Requirement already satisfied: certifi in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from roboflow) (2026.5.20)
# Requirement already satisfied: idna==3.7 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from roboflow) (1.5.0)
# Requirement already satisfied: matplotlib in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from roboflow) (3.10.9)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from roboflow) (2.4.6)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from roboflow) (12.2.0)
# Requirement already satisfied: pi-heif<2 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from roboflow) (1.3.0)
# Requirement already satisfied: pillow-avif-plugin<2 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from roboflow) (1.5.5)
# Requirement already satisfied: python-dateutil in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from roboflow) (1.2.2)
# Requirement already satisfied: requests in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from roboflow) (2.34.2)
# Requirement already satisfied: six in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from roboflow) (2.7.0)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from roboflow) (4.68.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests_toolbelt in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: typer<0.26,>=0.12.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from roboflow) (0.25.1)
# Requirement already satisfied: click>=8.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from roboflow) (8.4.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from typer<0.26,>=0.12.0->roboflow) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from typer<0.26,>=0.12.0->roboflow) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from typer<0.26,>=0.12.0->roboflow) (0.0.4)
# Requirement already satisfied: colorama in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from click>=8.0->roboflow) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from matplotlib->roboflow) (4.63.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from matplotlib->roboflow) (26.2)
# Requirement already satisfied: pyparsing>=3 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from matplotlib->roboflow) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\aarav\dev\learn\soccer_analysis\.venv\lib\site-packages (from requests->roboflow) (3.4.7)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="ITMTDhcWCh3Ndvn4K2NG")
project = rf.workspace("ilyes-talbi-ptwsp").project("futbol-players")
version = project.version(9)
dataset = version.download("yolo26")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in futbol-players-9 to yolo26:: 100%|██████████| 9489/9489 [00:02<00:00, 3344.64it/s]
# Extracting Dataset Version Zip to futbol-players-9 in yolo26:: 100%|██████████| 792/792 [00:00<00:00, 987.05it/s]

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
# Out:
# True
# 1
# NVIDIA RTX 1000 Ada Generation Laptop GPU

# %%
dataset.location
# Out:
# 'c:\\Users\\aarav\\Dev\\Learn\\soccer_analysis\\training\\futbol-players-9'

# %%
from ultralytics import YOLO

model = YOLO("yolo26m.pt")
model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=100,
    imgsz=640,
    batch=8,
    device=0,
    workers=4,
    cache="disk",
    patience=10
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26m.pt to 'yolo26m.pt': 100% ━━━━━━━━━━━━ 42.2MB 3.4MB/s 12.6s2.5s<0.1sss
# New https://pypi.org/project/ultralytics/8.4.63 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.61  Python-3.13.5 torch-2.12.0+cu130 CUDA:0 (NVIDIA RTX 1000 Ada Generation Laptop GPU, 6141MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=disk, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=c:\Users\aarav\Dev\Learn\soccer_analysis\training\futbol-players-9/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26m.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train-8, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\aarav\Dev\Learn\soccer_analysis\training\runs\detect\train-8, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1974784  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   2803242  ultralytics.nn.modules.head.Detect           [3, 1, True, [256, 512, 512]]
# YOLO26m summary: 280 layers, 21,777,514 parameters, 21,777,514 gradients, 74.7 GFLOPs
#
# Transferred 756/768 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 75.636.9 MB/s, size: 22.8 KB)
# train: Scanning C:\Users\aarav\Dev\Learn\soccer_analysis\training\futbol-players-9\train\labels.cache... 341 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 341/341 130.0Mit/s 0.0s
# train: Caching images (0.2GB Disk): 100% ━━━━━━━━━━━━ 341/341 19.1Kit/s 0.0s
# val: Fast image access  (ping: 0.20.1 ms, read: 18.96.8 MB/s, size: 13.6 KB)
# val: Scanning C:\Users\aarav\Dev\Learn\soccer_analysis\training\futbol-players-9\valid\labels.cache... 33 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 33/33 9.2Mit/s 0.0s
# val: Caching images (0.0GB Disk): 100% ━━━━━━━━━━━━ 33/33 11.9Kit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 124 weight(decay=0.0), 136 weight(decay=0.0005), 136 bias(decay=0.0)
# Plotting labels to C:\Users\aarav\Dev\Learn\soccer_analysis\training\runs\detect\train-8\labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to C:\Users\aarav\Dev\Learn\soccer_analysis\training\runs\detect\train-8
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      12.8G      1.793      2.515   0.005661          5        640: 100% ━━━━━━━━━━━━ 43/43 11.7s/it 8:2311.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.3s/it 15.8s<13.4s
#                    all         33        407       0.37       0.48      0.465      0.224
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      6.32G        1.7      1.226   0.005281          5        640: 100% ━━━━━━━━━━━━ 43/43 3.2s/it 2:192.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.6s/it 7.8s7.1ss
#                    all         33        407      0.659      0.677      0.701      0.379
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      6.29G      1.669     0.9489   0.005007          5        640: 100% ━━━━━━━━━━━━ 43/43 3.4s/it 2:272.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.5s/it 7.5s6.6ss
#                    all         33        407      0.763       0.76      0.763      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      6.29G      1.778     0.9233   0.005376          5        640: 100% ━━━━━━━━━━━━ 43/43 2.9s/it 2:061.8sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.5s/it 7.4s6.5ss
#                    all         33        407      0.671      0.845      0.798      0.423
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      6.29G      1.672     0.8113   0.005406          5        640: 100% ━━━━━━━━━━━━ 43/43 3.0s/it 2:102.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.6s/it 7.7s6.6ss
#                    all         33        407      0.832      0.867       0.89      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      6.29G      1.648     0.7115   0.005258          5        640: 100% ━━━━━━━━━━━━ 43/43 2.8s/it 2:022.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.0s/it 15.0s<12.3s
#                    all         33        407      0.845      0.851      0.867      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      6.29G        1.6     0.6357    0.00493          5        640: 100% ━━━━━━━━━━━━ 43/43 3.2s/it 2:182.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.6s/it 7.8s5.4s7s
#                    all         33        407      0.945      0.835      0.893      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      6.29G      1.586     0.6254   0.004896          5        640: 100% ━━━━━━━━━━━━ 43/43 3.4s/it 2:243.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.3s/it 7.0s5.6s7s
#                    all         33        407      0.959      0.853      0.906      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      6.26G      1.605     0.6039   0.005089          5        640: 100% ━━━━━━━━━━━━ 43/43 4.0s/it 2:523.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.2s/it 21.5s<19.9s
#                    all         33        407      0.909      0.886      0.923      0.492
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      6.29G      1.593      0.593   0.004861          5        640: 100% ━━━━━━━━━━━━ 43/43 4.2s/it 3:023.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.4s/it 7.3s5.5s5s
#                    all         33        407      0.863       0.83      0.885      0.509
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      6.29G      1.514     0.5707    0.00461          5        640: 100% ━━━━━━━━━━━━ 43/43 3.6s/it 2:352.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.5s/it 7.5s6.1s3s
#                    all         33        407      0.884      0.879      0.902      0.496
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      6.29G      1.523     0.5526   0.004642          5        640: 100% ━━━━━━━━━━━━ 43/43 3.7s/it 2:383.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.5s/it 7.4s5.6s0s
#                    all         33        407        0.9       0.91      0.903      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      6.29G        1.5     0.5534   0.004531          5        640: 100% ━━━━━━━━━━━━ 43/43 4.2s/it 3:024.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 6.4s/it 19.2s6.9s2
#                    all         33        407      0.903      0.886      0.926      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      6.29G      1.493      0.531   0.004518          5        640: 100% ━━━━━━━━━━━━ 43/43 4.2s/it 3:003.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.9s/it 14.6s5.7s4
#                    all         33        407      0.924      0.858      0.915      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      6.29G      1.483     0.5334   0.004512          5        640: 100% ━━━━━━━━━━━━ 43/43 4.2s/it 2:603.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.6s/it 7.7s4.9s9s
#                    all         33        407      0.955      0.902      0.936      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      6.29G       1.51     0.5551   0.004553          5        640: 100% ━━━━━━━━━━━━ 43/43 4.8s/it 3:283.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.7s/it 5.0s4.3ss
#                    all         33        407      0.902      0.881      0.904      0.491
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      6.26G      1.514     0.5431   0.004536          5        640: 100% ━━━━━━━━━━━━ 43/43 4.4s/it 3:092.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1s/it 3.3s2.9ss
#                    all         33        407      0.927      0.883      0.927      0.499
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      6.29G      1.449     0.5044   0.004363          5        640: 100% ━━━━━━━━━━━━ 43/43 4.2s/it 3:032.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.3s/it 3.8s3.5ss
#                    all         33        407      0.928      0.906      0.943      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      6.29G      1.435     0.4865   0.004218          5        640: 100% ━━━━━━━━━━━━ 43/43 3.9s/it 2:473.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.5s/it 4.5s4.1ss
#                    all         33        407      0.939      0.896      0.922      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      6.29G      1.429      0.491   0.004071          5        640: 100% ━━━━━━━━━━━━ 43/43 3.9s/it 2:472.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1s/it 3.4s3.1ss
#                    all         33        407      0.933      0.894      0.935      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      6.29G      1.404     0.4918   0.004006          5        640: 100% ━━━━━━━━━━━━ 43/43 4.4s/it 3:082.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1s/it 3.4s3.2ss
#                    all         33        407      0.923      0.891      0.943      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      6.29G      1.424     0.5141   0.004141          5        640: 100% ━━━━━━━━━━━━ 43/43 3.5s/it 2:292.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.6s/it 16.9s8.2s
#                    all         33        407      0.916      0.877        0.9      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      6.29G      1.466     0.5174   0.004225          5        640: 100% ━━━━━━━━━━━━ 43/43 3.9s/it 2:471.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.0s/it 3.1s2.8ss
#                    all         33        407      0.934      0.904       0.93      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      6.29G      1.398     0.4916   0.004209          5        640: 100% ━━━━━━━━━━━━ 43/43 4.6s/it 3:182.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.2s/it 3.5s3.3ss
#                    all         33        407      0.929      0.883      0.929      0.502
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      6.26G      1.447     0.4846    0.00425          5        640: 100% ━━━━━━━━━━━━ 43/43 3.8s/it 2:432.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.2s/it 3.5s3.2ss
#                    all         33        407      0.955      0.907      0.928      0.541
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      6.29G      1.427     0.4629   0.004404          5        640: 100% ━━━━━━━━━━━━ 43/43 4.1s/it 2:584.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1s/it 3.4s3.3ss
#                    all         33        407      0.907      0.904      0.922      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      6.29G      1.411     0.4687   0.004039          5        640: 100% ━━━━━━━━━━━━ 43/43 437.1s/it 5:13:174ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.2s/it 3.7s3.3ss
#                    all         33        407      0.926      0.911      0.921      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      6.29G      1.374     0.4638   0.004004          5        640: 100% ━━━━━━━━━━━━ 43/43 7.3s/it 5:122.5ss44
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.3s/it 7.0s4.7s
#                    all         33        407      0.937      0.892      0.938      0.541
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      6.29G      1.343     0.4536    0.00398          5        640: 100% ━━━━━━━━━━━━ 43/43 7.5s/it 5:224.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 8.9s/it 26.7s<24.8s
#                    all         33        407      0.974      0.846      0.916      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      6.29G      1.338     0.4354   0.004106          5        640: 100% ━━━━━━━━━━━━ 43/43 3.5s/it 2:312.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.1s/it 9.2s9.0s6s
#                    all         33        407      0.895      0.905      0.937      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      6.29G       1.34     0.4308   0.003869          5        640: 100% ━━━━━━━━━━━━ 43/43 4.3s/it 3:044.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.6s/it 10.9s<10.6s
#                    all         33        407      0.936       0.92      0.943      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      6.29G      1.374     0.4539   0.004165          5        640: 100% ━━━━━━━━━━━━ 43/43 4.1s/it 2:562.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.5s/it 10.6s<10.1s
#                    all         33        407      0.883      0.937      0.946      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      6.26G      1.368     0.4503   0.003892          5        640: 100% ━━━━━━━━━━━━ 43/43 3.8s/it 2:453.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.9s/it 11.7s<11.1s
#                    all         33        407      0.933      0.886       0.93      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      6.29G      1.291     0.4469   0.003903          5        640: 100% ━━━━━━━━━━━━ 43/43 4.4s/it 3:113.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.1s/it 9.4s9.0s3s
#                    all         33        407      0.949      0.888      0.909      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      6.29G      1.338      0.448   0.003865          5        640: 100% ━━━━━━━━━━━━ 43/43 3.4s/it 2:273.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.9s/it 17.7s<12.7s
#                    all         33        407      0.917        0.9      0.907      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      6.29G      1.319     0.4323   0.003793          5        640: 100% ━━━━━━━━━━━━ 43/43 3.6s/it 2:352.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.3s/it 6.9s6.2ss
#                    all         33        407      0.954      0.899      0.927      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      6.29G      1.321     0.4268   0.003799          5        640: 100% ━━━━━━━━━━━━ 43/43 3.7s/it 2:412.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.3s/it 12.9s4.3s6
#                    all         33        407      0.931      0.927      0.935      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      6.25G      1.304     0.4315   0.003975          8        640: 58% ━━━━━━╸───── 25/43 2.2it/s 1:25<8.2ss
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 from ultralytics import YOLO
#       2
#       3 model = YOLO("yolo26m.pt")
# ----> 4 model.train(
#       5     data=f"{dataset.location}/data.yaml",
#       6     epochs=100,
#       7     imgsz=640,
#
# File c:\Users\aarav\Dev\Learn\soccer_analysis\.venv\Lib\site-packages\ultralytics\engine\model.py:792, in Model.train(self, trainer, **kwargs)
#     789     self.trainer.model = self.trainer.get_model(weights=weights, cfg=self.model.yaml)
#     790     self.model = self.trainer.model
# --> 792 self.trainer.train()
#     793 # Update model and cfg after training
#     794 if RANK in {-1, 0}:
#
# File c:\Users\aarav\Dev\Learn\soccer_analysis\.venv\Lib\site-packages\ultralytics\engine\trainer.py:246, in BaseTrainer.train(self)
#     243             ddp_cleanup(self, str(file))
#     245 else:
# --> 246     self._do_train()
#
# File c:\Users\aarav\Dev\Learn\soccer_analysis\.venv\Lib\site-packages\ultralytics\engine\trainer.py:450, in BaseTrainer._do_train(self)
#     448     loss, self.loss_items = unwrap_model(self.model).loss(batch, preds)
#     449 else:
# --> 450     loss, self.loss_items = self.model(batch)
#     451 self.loss = loss.sum()
#     452 if RANK != -1:
#
# File c:\Users\aarav\Dev\Learn\soccer_analysis\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File c:\Users\aarav\Dev\Learn\soccer_analysis\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File c:\Users\aarav\Dev\Learn\soccer_analysis\.venv\Lib\site-packages\ultralytics\nn\tasks.py:143, in BaseModel.forward(self, x, *args, **kwargs)
#     130 """Perform forward pass of the model for either training or inference.
#     131
#     132 If x is a dict, calculates and returns the loss for training. Otherwise, returns predictions for inference.
#    (...)    140     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     141 """
#     142 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 143     return self.loss(x, *args, **kwargs)
#     144 return self.predict(x, *args, **kwargs)
#
# File c:\Users\aarav\Dev\Learn\soccer_analysis\.venv\Lib\site-packages\ultralytics\nn\tasks.py:336, in BaseModel.loss(self, batch, preds)
#     333     self.criterion = self.init_criterion()
#     335 if preds is None:
# --> 336     preds = self.forward(batch["img"])
#     337 return self.criterion(preds, batch)
#
# File c:\Users\aarav\Dev\Learn\soccer_analysis\.venv\Lib\site-packages\ultralytics\nn\tasks.py:144, in BaseModel.forward(self, x, *args, **kwargs)
#     142 if isinstance(x, dict):  # for cases of training and validating while training.
#     143     return self.loss(x, *args, **kwargs)
# --> 144 return self.predict(x, *args, **kwargs)
#
# File c:\Users\aarav\Dev\Learn\soccer_analysis\.venv\Lib\site-packages\ultralytics\nn\tasks.py:161, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     159 if augment:
#     160     return self._predict_augment(x)
# --> 161 return self._predict_once(x, profile, visualize, embed)
#
# File c:\Users\aarav\Dev\Learn\soccer_analysis\.venv\Lib\site-packages\ultralytics\nn\tasks.py:183, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     181 if profile:
#     182     self._profile_one_layer(m, x, dt)
# --> 183 x = m(x)  # run
#     184 y.append(x if m.i in self.save else None)  # save output
#     185 if visualize:
#
# File c:\Users\aarav\Dev\Learn\soccer_analysis\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File c:\Users\aarav\Dev\Learn\soccer_analysis\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File c:\Users\aarav\Dev\Learn\soccer_analysis\.venv\Lib\site-packages\ultralytics\nn\modules\conv.py:78, in Conv.forward(self, x)
#      69 def forward(self, x):
#      70     """Apply convolution, batch normalization and activation to input tensor.
#      71
#      72     Args:
#    (...)     76         (torch.Tensor): Output tensor.
#      77     """
# ---> 78     return self.act(self.bn(self.conv(x)))
#
# File c:\Users\aarav\Dev\Learn\soccer_analysis\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File c:\Users\aarav\Dev\Learn\soccer_analysis\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File c:\Users\aarav\Dev\Learn\soccer_analysis\.venv\Lib\site-packages\torch\nn\modules\activation.py:475, in SiLU.forward(self, input)
#     471 def forward(self, input: Tensor) -> Tensor:
#     472     """
#     473     Runs the forward pass.
#     474     """
# --> 475     return F.silu(input, inplace=self.inplace)
#
# File c:\Users\aarav\Dev\Learn\soccer_analysis\.venv\Lib\site-packages\torch\nn\functional.py:2396, in silu(input, inplace)
#    2394     return handle_torch_function(silu, (input,), input, inplace=inplace)
#    2395 if inplace:
# -> 2396     return torch._C._nn.silu_(input)
#    2397 return torch._C._nn.silu(input)
#
# KeyboardInterrupt:
